# %% [markdown]
# <a href="https://colab.research.google.com/github/rlaxogud0909/test/blob/master/1%EC%A3%BC%EC%B0%A8%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.언어
# 대표적인 서비스는 챗봇이다. 챗봇이란 채팅하는 봇이라는 뜻이다. 마치 인간과 비슷하게 사용자와 직접 대화를 나눌 수 있는 컴퓨터 프로그램이다. 챗봇은 우리가 질문하면 원하는 대답을 해준다. 여기서 자연어 처리라는 기술을 쓴다. 여기서 자연어 처리 기술에서 인간처럼 감정을 느낄 수 있는지 대해 공부해보고 싶다.
#
# 2. 음성
# 현재 음성 AI는 많이 볼 수 있다. 스마트폰의 AI인 ‘시리’,‘빅스비’ 등이 있고 AI 스피커 등이 있다. 이뿐만 아니라 많은 분야에서 음성 인공지능은 많이 쓰이고 있다. 음성 분야의 AI 스피커가 대표적이라고 생각한다. 내게 흥미를 끄는 기술은 사람의 단어와 목소리 톤 등을 분석해 감정까지 잡아내는 기능이다. 인공지능이 어떻게 목소리 톤을 구분하는지 궁금하다 만약 단어와 톤을 반대로 했을 때 인공지능은 사람의 감정을 어떻게 받아들이는지 공부해보고 싶다.
#
# 3. 이미지
# 사물을 보고 스스로 인식하는 ‘AI 이미지 분석 기술’이다. 현재 AI 이미지 분석 기술은 보안 검색대, 얼굴 인식, 이미지 분류 등 많은 산업 분야에 사용되는 것을 볼 수 있다. AI 이미지 분석 핵심 기술은 ‘노이즈’ 이다. 노이즈란 스마트폰에서 화면을 확대할 시 화질 저하 현상이 생기는 현상이다. 즉 노이즈가 심하면 이미지를 잘못 인식하는 경우도 있다. 또 다른 방법은  이미지의 특징을 포착하고 추상화하는 것이다. 예를 들면 고양이 얼굴의 경우 뾰족한 귀, 가는눈, 수염 등 고양이를 대표하는 특징을 잘 포착하고 이를 추상화하여 다양한 품종의 고양이 얼굴을 모두 고양이로 판별하게끔 만들어야 한다. 나는 노이즈가 심한 이미지를 인공지능이 다시 복원할 수 있는지 그 기술을 배워 보고 싶다.
#
# 4. 자율주행
# 현재 자율주행 분야에서는 ‘자율주행 자동차’에 대한 관심이 매우 크다. 현재 세계 각국 유명 자동차회사들은 자율주행 자동차의 도입을 위한 연구 개발을 끊임없이 진행 중이다. 자율주행 기술은 자율화된 수준에 따라 크게 0~5단계로 나눌 수 있다. 2단계까지는 대부분 우리가 흔히 볼 수 있고 현재 양산하는 자동차라고 볼 수 있다. 3단계는 조건부 자동화이다. 자동차 내 인공지능에 의한 제한적인 자율주행이 가능하나 특정 상황에 따라 반드시 운전자의 개입이 필요하다. 운전자의 개입이 어디까지 필요 없는지 공부해보고 싶고 더 나아가 운전자의 개입을 더 많이 줄 수 있도록 연구해보고 싶다.
